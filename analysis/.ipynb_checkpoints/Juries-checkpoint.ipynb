# %%
## restructure CSV file

import csv

file = open('results_new_combined.csv','r')

csvfile = csv.DictReader(file)

### Jurors
users = {}
juries = set()

### Juries
# users = {'3': [{id:juror1,group_id: 3}, {id:juror2,pref:blah}],
#           'group_id': [{id:juror1,pref:blah}, {id:juror2,pref:blah}] }



## Condition
scaleable_vote = []
immersive_vote = []

immersive = {'immersive_difficulty': [],
           'immersive_time': [],
           'immersive_satisfaction': [],
             'immersive0': [],
             'immersive1': [],
             'immersive2': [],
             'immersive3': [],
             'immersive4': [],
             'immersive5': [],
             }
scaleable = {'scaleable_difficulty': [],
           'scaleable_time': [],
           'scaleable_satisfaction': [],
             'scaleable0': [],
             'scaleable1': [],
             'scaleable2': [],
             'scaleable3': [],
             'scaleable4': [],
             'scaleable5': [],
             }
control = {'control_difficulty': [],
           'control_time': [],
           'control_satisfaction': [],
           'control0': [],
           'control1': [],
           'control2': [],
           'control3': [],
           'control4': [],
           'control5': [],
           }

## Overall
avg_time_spent = []
enforcement = []
recommendation = []

pref = {'control': 0,
        'scaleable': 0,
        'immersive': 0}
nonpref = {'control': 0,
        'scaleable': 0,
        'immersive': 0}

## Create master list of all juries
# for row in csvfile:
#     juries.add(row['group_id'])

# print(juries)


for row in csvfile:
    ## create dictionary by users
    users[row['\ufeffmturk']] = row
    
    
    ## create dictionary by juries
#     users[row['group_id']] = row
    
    
    ## average time across all jurors
    t = row['time_spent']
    avg_time_spent.append(t)
    
    
    ### User Preference
    if 'Blind Voting' in row['complete_pref']:
        pref['scaleable'] += 1
    elif 'No Jury' in row['complete_pref']:
        pref['control'] += 1
    elif 'Deliberating' in row['complete_pref']:
        pref['immersive'] += 1

    if 'Blind Voting' in row['complete_nonpref']:
        nonpref['scaleable'] += 1
    elif 'No Jury' in row['complete_nonpref']:
        nonpref['control'] += 1
    elif 'Deliberating' in row['complete_nonpref']:
        nonpref['immersive'] += 1

    try:
        enforcement.append(float(row['scaleable_vote']))
        recommendation.append(float(row['immersive_vote']))
    except Exception:
        pass
    
    
    ### Immersive
    if row['immersive_difficulty'].strip() != '0':
        immersive['immersive_difficulty'].append(int(row['immersive_difficulty']))
    if row['immersive_time'].strip() != '0':
        immersive['immersive_time'].append(int(row['immersive_time']))
    if row['immersive_satisfaction'].strip() != '0':
        immersive['immersive_satisfaction'].append(int(row['immersive_satisfaction']))
    if row['immersive0'].strip() != '0':
        immersive['immersive0'].append(int(row['immersive0']))
    if row['immersive1'].strip() != '0':
        immersive['immersive1'].append(int(row['immersive1']))
    if row['immersive3'].strip() != '0':
        immersive['immersive2'].append(int(row['immersive2']))
    if row['immersive3'].strip() != '0':
        immersive['immersive3'].append(int(row['immersive3']))
    if row['immersive4'].strip() != '0':
        immersive['immersive4'].append(int(row['immersive4']))
    if row['immersive5'].strip() != '0':
        immersive['immersive5'].append(int(row['immersive5']))

    ### Scaleable
    if row['scaleable_difficulty'].strip() != '0':
        scaleable['scaleable_difficulty'].append(int(row['scaleable_difficulty']))
    if row['scaleable_time'].strip() != '0':
        scaleable['scaleable_time'].append(int(row['scaleable_time']))
    if row['scaleable_satisfaction'].strip() != '0':
        scaleable['scaleable_satisfaction'].append(int(row['scaleable_satisfaction']))
    if row['scaleable0'].strip() != '0':
        scaleable['scaleable0'].append(int(row['scaleable0']))
    if row['scaleable1'].strip() != '0':
        scaleable['scaleable1'].append(int(row['scaleable1']))
    if row['scaleable2'].strip() != '0':
        scaleable['scaleable2'].append(int(row['scaleable2']))
    if row['scaleable3'].strip() != '0':
        scaleable['scaleable3'].append(int(row['scaleable3']))
    if row['scaleable4'].strip() != '0':
        scaleable['scaleable4'].append(int(row['scaleable4']))
    if row['scaleable5'].strip() != '0':
        scaleable['scaleable5'].append(int(row['scaleable5']))
    
    ### Control
    if row['control_difficulty'].strip() != '0':
        control['control_difficulty'].append(int(row['control_difficulty']))
    if row['control_time'].strip() != '0':
        control['control_time'].append(int(row['control_time']))
    if row['control_satisfaction'].strip() != '0':
        control['control_satisfaction'].append(int(row['control_satisfaction']))
    if row['control0'].strip() != '0':
        control['control0'].append(int(row['control0']))
    if row['control1'].strip() != '0':
        control['control1'].append(int(row['control1']))
    if row['control2'].strip() != '0':
        control['control2'].append(int(row['control2']))
    if row['control3'].strip() != '0':
        control['control3'].append(int(row['control3']))
    if row['control4'].strip() != '0':
        control['control4'].append(int(row['control4']))
    if row['control5'].strip() != '0':
        control['control5'].append(int(row['control5']))
    
print(users)
print("total users", len(users))
# Out:
# {'A326O3VWP8TO8N': OrderedDict([('\ufeffmturk', 'A326O3VWP8TO8N'), ('time_spent', '0:34:06'), ('notes', ''), ('group_id', '3'), ('group_round1', 'No Jury'), ('group_round2', 'Blind Voting'), ('group_round3', 'Deliberating'), ('case1', 'christchurch'), ('case2', 'pepe'), ('case3', 'momo'), ('chat_username', 'tak1'), ('age', '25-34'), ('gender', 'Male'), ('education', 'College'), ('political', 'Democrat'), ('political_engagement', 'Interested'), ('confidence', 'Moderately'), ('moral0', '4'), ('moral1', '3'), ('moral2', '4'), ('moral3', '2'), ('moral4', '2'), ('moral5', '4'), ('control_difficulty', '1'), ('control_time', '1'), ('control_satisfaction', '5'), ('control0', '4'), ('control1', '4'), ('control2', '4'), ('control3', '4'), ('control4', '4'), ('control5', '4'), ('scaleable_vote', '9.5'), ('scaleable_content_unlist', 'FALSE'), ('scaleable_content_delete', 'TRUE'), ('scaleable_content_report', 'FALSE'), ('scaleable_user_warn', 'FALSE'), ('scaleable_user_ban', 'TRUE'), ('scaleable_user_permaban', 'FALSE'), ('scaleable_justification', 'I thought it was rather toxic and needed to be removed from the site.'), ('scaleable_difficulty', '2'), ('scaleable_time', '5'), ('scaleable_satisfaction', '4'), ('scaleable0', '4'), ('scaleable1', '3'), ('scaleable2', '4'), ('scaleable3', '4'), ('scaleable4', '4'), ('scaleable5', '4'), ('immersive_vote', '6'), ('immersive_content_unlist', 'TRUE'), ('immersive_content_delete', 'FALSE'), ('immersive_content_report', 'FALSE'), ('immersive_user_warn', 'TRUE'), ('immersive_user_ban', 'FALSE'), ('immersive_user_permaban', 'FALSE'), ('immersive_justification', "I felt like the post wasn't bad enough to remove but I would still not want other innocent people to see it if they're not looking of rit.."), ('immersive_difficulty', '4'), ('immersive_time', '5'), ('immersive_satisfaction', '3'), ('immersive_convo', '3'), ('immersive_trust', '3'), ('immersive0', '4'), ('immersive1', '5'), ('immersive2', '4'), ('immersive3', '5'), ('immersive4', '5'), ('immersive5', '5'), ('complete_pref', 'Round 3 (Deliberating)'), ('complete_prefwhy', 'It would be thoroughly vetted before making a decision.'), ('complete_nonpref', 'Round 1 (No Jury)'), ('complete_nonprefwhy', 'Some legitimate content can get removed from the site this way.'), ('complete_participate0', 'FALSE'), ('complete_participate1', 'FALSE'), ('complete_participate2', 'TRUE'), ('complete_participate3', 'FALSE'), ('complete_participate4', 'FALSE'), ('complete_enf_rec', '5'), ('complete_enf_enf', '3'), ('complete_enf_why', 'I still feel like it would be up to the user to self moderate sometimes as this is a subjective task.'), ('complete3', '4'), ('complete_confidence', '4'), ('complete_familiarity', '3'), ('complete_comments', ''), ('email', 'razaeria@gmail.com'), ('num_chat_messages', '3'), ('num_chat_words', '11')]), 'A2YUCJ28XANFOX': OrderedDict([('\ufeffmturk', 'A2YUCJ28XANFOX'), ('time_spent', '1:07:55'), ('notes', 'skipped Control survey'), ('group_id', '3'), ('group_round1', 'No Jury'), ('group_round2', 'Blind Voting'), ('group_round3', 'Deliberating'), ('case1', 'christchurch'), ('case2', 'pepe'), ('case3', 'momo'), ('chat_username', 'Liz'), ('age', '25-34'), ('gender', 'Female'), ('education', 'High school'), ('political', 'Republican'), ('political_engagement', 'Interested'), ('confidence', 'Very Much'), ('moral0', '5'), ('moral1', '5'), ('moral2', '4'), ('moral3', '3'), ('moral4', '3'), ('moral5', '5'), ('control_difficulty', '0'), ('control_time', '0'), ('control_satisfaction', '0'), ('control0', '0'), ('control1', '0'), ('control2', '0'), ('control3', '0'), ('control4', '0'), ('control5', '0'), ('scaleable_vote', '8'), ('scaleable_content_unlist', 'FALSE'), ('scaleable_content_delete', 'TRUE'), ('scaleable_content_report', 'FALSE'), ('scaleable_user_warn', 'FALSE'), ('scaleable_user_ban', 'FALSE'), ('scaleable_user_permaban', 'TRUE'), ('scaleable_justification', 'I think it seemed hateful and derogatory'), ('scaleable_difficulty', '1'), ('sc ...
# total users 90

# %%
# for row in csvfile:
#     users[row['\ufeffmturk']] = row
# #         t = row['time_spent']
# #         avg_time_spend.append()

    
#     ### User Preference
#     if 'Blind Voting' in row['complete_pref']:
#         pref['scaleable'] += 1
#     elif 'No Jury' in row['complete_pref']:
#         pref['control'] += 1
#     elif 'Deliberating' in row['complete_pref']:
#         pref['immersive'] += 1

#     if 'Blind Voting' in row['complete_nonpref']:
#         nonpref['scaleable'] += 1
#     elif 'No Jury' in row['complete_nonpref']:
#         nonpref['control'] += 1
#     elif 'Deliberating' in row['complete_nonpref']:
#         nonpref['immersive'] += 1

#     try:
#         enforcement.append(float(row['scaleable_vote']))
#         recommendation.append(float(row['immersive_vote']))
#     except Exception:
#         pass
    
#     ### Immersive
#     if row['immersive_difficulty'].strip() != '0':
#         immersive['immersive_difficulty'].append(int(row['immersive_difficulty']))
#     if row['immersive_time'].strip() != '0':
#         immersive['immersive_time'].append(int(row['immersive_time']))
#     if row['immersive_satisfaction'].strip() != '0':
#         immersive['immersive_satisfaction'].append(int(row['immersive_satisfaction']))
#     if row['immersive0'].strip() != '0':
#         immersive['immersive0'].append(int(row['immersive0']))
#     if row['immersive1'].strip() != '0':
#         immersive['immersive1'].append(int(row['immersive1']))
#     if row['immersive3'].strip() != '0':
#         immersive['immersive2'].append(int(row['immersive2']))
#     if row['immersive3'].strip() != '0':
#         immersive['immersive3'].append(int(row['immersive3']))
#     if row['immersive4'].strip() != '0':
#         immersive['immersive4'].append(int(row['immersive4']))
#     if row['immersive5'].strip() != '0':
#         immersive['immersive5'].append(int(row['immersive5']))

#     ### Scaleable
#     if row['scaleable_difficulty'].strip() != '0':
#         scaleable['scaleable_difficulty'].append(int(row['scaleable_difficulty']))
#     if row['scaleable_time'].strip() != '0':
#         scaleable['scaleable_time'].append(int(row['scaleable_time']))
#     if row['scaleable_satisfaction'].strip() != '0':
#         scaleable['scaleable_satisfaction'].append(int(row['scaleable_satisfaction']))
#     if row['scaleable0'].strip() != '0':
#         scaleable['scaleable0'].append(int(row['scaleable0']))
#     if row['scaleable1'].strip() != '0':
#         scaleable['scaleable1'].append(int(row['scaleable1']))
#     if row['scaleable2'].strip() != '0':
#         scaleable['scaleable2'].append(int(row['scaleable2']))
#     if row['scaleable3'].strip() != '0':
#         scaleable['scaleable3'].append(int(row['scaleable3']))
#     if row['scaleable4'].strip() != '0':
#         scaleable['scaleable4'].append(int(row['scaleable4']))
#     if row['scaleable5'].strip() != '0':
#         scaleable['scaleable5'].append(int(row['scaleable5']))
    
#     ### Control
#     if row['control_difficulty'].strip() != '0':
#         control['control_difficulty'].append(int(row['control_difficulty']))
#     if row['control_time'].strip() != '0':
#         control['control_time'].append(int(row['control_time']))
#     if row['control_satisfaction'].strip() != '0':
#         control['control_satisfaction'].append(int(row['control_satisfaction']))
#     if row['control0'].strip() != '0':
#         control['control0'].append(int(row['control0']))
#     if row['control1'].strip() != '0':
#         control['control1'].append(int(row['control1']))
#     if row['control2'].strip() != '0':
#         control['control2'].append(int(row['control2']))
#     if row['control3'].strip() != '0':
#         control['control3'].append(int(row['control3']))
#     if row['control4'].strip() != '0':
#         control['control4'].append(int(row['control4']))
#     if row['control5'].strip() != '0':
#         control['control5'].append(int(row['control5']))
    
# #     f.write()

# print("total users", len(users))
# Out:
# total users 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('results_new_combined.csv')

## first row of sample data
df.iloc[0]

## get dtypes
df.dtypes
# Out:
# mturk                     object
# time_spent                object
# notes                     object
# group_id                   int64
# group_round1              object
# group_round2              object
# group_round3              object
# case1                     object
# case2                     object
# case3                     object
# chat_username             object
# age                       object
# gender                    object
# education                 object
# political                 object
# political_engagement      object
# confidence                object
# moral0                     int64
# moral1                     int64
# moral2                     int64
# moral3                     int64
# moral4                     int64
# moral5                     int64
# control_difficulty         int64
# control_time               int64
# control_satisfaction       int64
# control0                   int64
# control1                   int64
# control2                   int64
# control3                   int64
#                            ...
# immersive_difficulty       int64
# immersive_time             int64
# immersive_satisfaction     int64
# immersive_convo            int64
# immersive_trust            int64
# immersive0                 int64
# immersive1                 int64
# immersive2                 int64
# immersive3                 int64
# immersive4                 int64
# immersive5                 int64
# complete_pref             object
# complete_prefwhy          object
# complete_nonpref          object
# complete_nonprefwhy       object
# complete_participate0       bool
# complete_participate1       bool
# complete_participate2       bool
# complete_participate3       bool
# complete_participate4       bool
# complete_enf_rec           int64
# complete_enf_enf           int64
# complete_enf_why          object
# complete3                  int64
# complete_confidence        int64
# complete_familiarity       int64
# complete_comments         object
# email                     object
# num_chat_messages          int64
# num_chat_words             int64
# Length: 87, dtype: object

# %%
# num of rows (participants)
df.shape[0]
# Out:
# 90

# %%
## num of jurors in each jury (series)
jury_size = df.groupby(['group_id']).size()
jury_size
# Out:
# pandas.core.series.Series

# %%
part0 = data['complete_participate0'].value_counts()
part1 = data['complete_participate1'].value_counts()
part2 = data['complete_participate2'].value_counts()
part3 = data['complete_participate3'].value_counts()
part4 = data['complete_participate4'].value_counts()


print("Yes, I would volunteer for it")
volunteer = part0[True] / (part0[True]+part0[False])
print(format(volunteer, '%'))

print("\n")

print("Yes, if I'm bored/have free time")
freetime = part1[True] / (part1[True]+part1[False])
print(format(freetime, '%'))

print("\n")

print("Yes, if I'm paid for my time")
paid = part2[True] / (part2[True]+part2[False])
print(format(paid, '%'))

print("\n")

print("Yes, if it's mandatory")
mandatory = part3[True] / (part3[True]+part3[False])
print(format(mandatory, '%'))


print("\n")

print("Not likely at all")
noparticipate = part4[True] / (part4[True]+part4[False])
print(format(noparticipate, '%'))
# Out:
# Yes, I would volunteer for it
# 21.875000%
#
#
# Yes, if I'm bored/have free time
# 34.375000%
#
#
# Yes, if I'm paid for my time
# 77.083333%
#
#
# Yes, if it's mandatory
# 9.375000%
#
#
# Not likely at all
# 3.125000%

# %%
print(df['complete_enf_rec'].value_counts())
print("mode:", df['complete_enf_rec'].mode())
print("median:", df['complete_enf_rec'].median())
print("mean:", df['complete_enf_rec'].mean())
# Out:
# 3    24
# 4    22
# 5    21
# 2    16
# 1     4
# 0     4
# Name: complete_enf_rec, dtype: int64
# mode: 0    3
# dtype: int64
# median: 3.0
# mean: 3.3076923076923075

# %%
print(df['complete_enf_enf'].value_counts())
print("mode:", df['complete_enf_enf'].mode())
print("median:", df['complete_enf_enf'].median())
print("mean:", df['complete_enf_enf'].mean())
# Out:
# 5    23
# 3    23
# 4    22
# 2    10
# 1     9
# 0     4
# Name: complete_enf_enf, dtype: int64
# mode: 0    3
# 1    5
# dtype: int64
# median: 3.0
# mean: 3.3076923076923075

# %%
bins = np.arange(0, df['control0'].max() + 1.5) - 0.5

plt.hist(df['complete_enf_enf'], bins)
plt.grid()

# %%
plt.boxplot(df['control0'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f76122ba5c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f76122bae48>,
#   <matplotlib.lines.Line2D at 0x7f76122c81d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f76122c8860>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f76122c8518>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f76122ba7b8>,
#   <matplotlib.lines.Line2D at 0x7f76122bab00>]}

# %%
# data['complete_prefwhy'].value_counts()
df['complete_prefwhy'].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-30049dff4dcc> in <module>()
# ----> 1 df['complete_prefwhy'].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-48-30049dff4dcc> in <lambda>(x)
# ----> 1 df['complete_prefwhy'].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
pd.DataFrame(df['complete_prefwhy'].dropna().apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0), columns=["count"]).sort_values(["count"], ascending=False)
# Out:
#               count
# to            100.0
# the            86.0
# I              64.0
# and            62.0
# a              44.0
# of             34.0
# It             31.0
#                28.0
# was            27.0
# it             27.0
# be             19.0
# more           18.0
# in             17.0
# think          17.0
# others         16.0
# other          15.0
# my             15.0
# is             15.0
# like           15.0
# people         15.0
# me             14.0
# with           14.0
# on             12.0
# that           12.0
# most           11.0
# opinions       11.0
# because        10.0
# for            10.0
# way            10.0
# feel            9.0
# ...             ...
# way,            1.0
# slightly        1.0
# yet             1.0
# end.            1.0
# voting.         1.0
# inconsistent    1.0
# know            1.0
# judge           1.0
# collection      1.0
# lot             1.0
# between         1.0
# feedback.       1.0
# seeing          1.0
# persuaded       1.0
# enjoy           1.0
# eliminates      1.0
# voters.         1.0
# faster          1.0
# results.        1.0
# Was             1.0
# differently     1.0
# No              1.0
# equally.        1.0
# mad             1.0
# myself          1.0
# small           1.0
# biased          1.0
# forth           1.0
# depending       1.0
# read            1.0
#
# [643 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['mturk', 'time_spent', 'notes', 'group_id', 'group_round1',
#        'group_round2', 'group_round3', 'case1', 'case2', 'case3',
#        'chat_username', 'age', 'gender', 'education', 'political',
#        'political_engagement', 'confidence', 'moral0', 'moral1', 'moral2',
#        'moral3', 'moral4', 'moral5', 'control_difficulty', 'control_time',
#        'control_satisfaction', 'control0', 'control1', 'control2', 'control3',
#        'control4', 'control5', 'scaleable_vote', 'scaleable_content_unlist',
#        'scaleable_content_delete', 'scaleable_content_report',
#        'scaleable_user_warn', 'scaleable_user_ban', 'scaleable_user_permaban',
#        'scaleable_justification', 'scaleable_difficulty', 'scaleable_time',
#        'scaleable_satisfaction', 'scaleable0', 'scaleable1', 'scaleable2',
#        'scaleable3', 'scaleable4', 'scaleable5', 'immersive_vote',
#        'immersive_content_unlist', 'immersive_content_delete',
#        'immersive_content_report', 'immersive_user_warn', 'immersive_user_ban',
#        'immersive_user_permaban', 'immersive_justification',
#        'immersive_difficulty', 'immersive_time', 'immersive_satisfaction',
#        'immersive_convo', 'immersive_trust', 'immersive0', 'immersive1',
#        'immersive2', 'immersive3', 'immersive4', 'immersive5', 'complete_pref',
#        'complete_prefwhy', 'complete_nonpref', 'complete_nonprefwhy',
#        'complete_participate0', 'complete_participate1',
#        'complete_participate2', 'complete_participate3',
#        'complete_participate4', 'complete_enf_rec', 'complete_enf_enf',
#        'complete_enf_why', 'complete3', 'complete_confidence',
#        'complete_familiarity', 'complete_comments', 'email',
#        'num_chat_messages', 'num_chat_words'],
#       dtype='object')

# %%
columns_to_keep = ['control0', 'control1', 'control2', 'control3',
       'control4', 'control5','scaleable0', 'scaleable1', 'scaleable2',
       'scaleable3', 'scaleable4', 'scaleable5','immersive0', 'immersive1',
       'immersive2', 'immersive3', 'immersive4', 'immersive5']

df2 = df[columns_to_keep]

# %%
dfs = []
for i in range(0, 6):
  related_columns = [x + str(i) for x in ["control", "scaleable", "immersive"]]
  dfs.append(df2[related_columns])

# %%
g = sns.pairplot(dfs[2])

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
# iris = sns.load_dataset("iris")
# g = sns.pairplot(iris)
# iris


sns.distplot(df['complete_enf_rec'], bins=5, kde=False, rug=True, label='Recommendation');
sns.distplot(df['complete_enf_enf'], bins=5, kde=False, rug=True, label='Enforcement');

# %%
col_demographics = ['age', 'gender', 'education', 'political',
       'political_engagement', 'confidence', 'moral0', 'moral1', 'moral2',
       'moral3', 'moral4', 'moral5','complete_confidence',
       'complete_familiarity']

df_demo = df[col_demographics]

df_demo[:0]
# Out:
# Empty DataFrame
# Columns: [age, gender, education, political, political_engagement, confidence, moral0, moral1, moral2, moral3, moral4, moral5, complete_confidence, complete_familiarity]
# Index: []

# %%
for i in col_demographics:
  print('\n' + i)
  results_i = df_demo[i].value_counts()
  print(results_i)
# Out:
# age
# 25-34    40
# 35-44    20
# 45-54    13
# 18-24    11
# 55-64     3
# Name: age, dtype: int64
#
# gender
# Male      60
# Female    26
# Name: gender, dtype: int64
#
# education
# College              45
# High school          32
# Grad/professional     8
# Some high school      2
# Name: education, dtype: int64
#
# political
# Democrat       43
# Republican     20
# Independent    19
# Libertarian     2
# Other           1
# Name: political, dtype: int64
#
# political_engagement
# Interested            42
# Very Interested       22
# Neutral               13
# Disinterested          7
# Very Disinterested     1
# Name: political_engagement, dtype: int64
#
# confidence
# Somewhat      33
# Very Much     32
# Moderately    14
# A Little       6
# Name: confidence, dtype: int64
#
# moral0
# 5    41
# 4    27
# 3    10
# 2     9
# 1     3
# 0     1
# Name: moral0, dtype: int64
#
# moral1
# 4    28
# 5    27
# 3    24
# 2     7
# 1     4
# 0     1
# Name: moral1, dtype: int64
#
# moral2
# 2    22
# 3    20
# 4    18
# 1    16
# 5    14
# 0     1
# Name: moral2, dtype: int64
#
# moral3
# 2    33
# 1    29
# 3    19
# 4     5
# 5     4
# 0     1
# Name: moral3, dtype: int64
#
# moral4
# 3    26
# 1    25
# 2    24
# 4    10
# 5     5
# 0     1
# Name: moral4, dtype: int64
#
# moral5
# 5    57
# 4    21
# 3     7
# 1     3
# 2     2
# 0     1
# Name: moral5, dtype: int64
#
# complete_confidence
# 5    44
# 4    26
# 3    10
# 2     5
# 0     4
# 1     2
# Name: complete_confidence, dtype: int64
#
# complete_familiarity
# 5    23
# 4    22
# 2    21
# 3    14
# 1     7
# 0     4
# Name: complete_familiarity, dtype: int64

# %%
enf_col = ['complete_enf_rec', 'complete_enf_enf']
df_enf = df['enf_col']

df_enf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'enf_col'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-6e3c897656cb> in <module>()
#       1 enf_col = ['complete_enf_rec', 'complete_enf_enf']
# ----> 2 df_enf = df['enf_col']
#       3
#       4 df_enf
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'enf_col'

# %%
ax = sns.scatterplot(x="confidence", y="complete_confidence", data=df_demo)

# %%
age = pd.DataFrame(df['age'].value_counts(dropna=True, sort=True).reset_index())
age.rename(index=str, columns={"index":"age", "age":"count"})
# Out:
#      age  count
# 0  25-34     40
# 1  35-44     20
# 2  45-54     13
# 3  18-24     11
# 4  55-64      3

# %%
unsatisfied = df.query("immersive_satisfaction == '1'").dropna()
satisfied = df.query("immersive_satisfaction == '5'").dropna()

satisfied['immersive_vote']
# Out:
# 2     4.5
# 4     8.0
# 21    6.5
# Name: immersive_vote, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

ax = sns.kdeplot(satisfied['immersive_satisfaction'], satisfied['immersive_vote'], cmap="Reds", shade=True, shade_lowest=False)

red = sns.color_palette("Reds")[-2]
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kernels.py:128: RuntimeWarning: invalid value encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1557: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1558: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1203: RuntimeWarning: invalid value encountered in less
#   under = np.nonzero(lev < self.zmin)[0]
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1205: RuntimeWarning: invalid value encountered in greater
#   over = np.nonzero(lev > self.zmax)[0]

# %%
sns.set(style="white")

sns.catplot(x="immersive_satisfaction", y="immersive_vote", hue="gender", kind="violin", data=df);

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-5d2ccada4210> in <module>()
#      14
#      15
# ---> 16 df['wordlist'] = df.apply(lambda row: multi(row['num'], row['theme'], axis=1))
#      17 print(df)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-16-5d2ccada4210> in <lambda>(row)
#      14
#      15
# ---> 16 df['wordlist'] = df.apply(lambda row: multi(row['num'], row['theme'], axis=1))
#      17 print(df)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ('num', 'occurred at index num')

# %%
import csv

with open('themes.csv') as csvfile:
  readCSV = csv.reader(csvfile, delimiter=',')
  next(readCSV, None)
  for row in readCSV:
    row[1] = row[1] + " "
    multiplier = int(row[0])
    print(multiplier * row[1].lower())
# Out:
# participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory participatory
# harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms
# rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness rightness
# collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective collective
# empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy empathy
# harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms
# individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism
# individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism individualism
# efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency efficiency
# liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty liberty
# conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation conversation
# harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms harms
# proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate proportionate
# human error human error human error human error human error human error human error human error human error human error human error human error human error human error human error human error human error
# peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust peer (dis)trust
# humans humans humans humans humans humans humans humans humans humans humans humans humans humans humans
# outcome outcome outcome outcome outcome outcome outcome outcome outcome outcome outcome outcome outcome outcome outcome
# unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased unbiased
# system system system system system system system system system system system system system system
# due process due process due process due process due process due process due process due process due process due process due process due process
# credible credible credible credible credible credible credible credible credible credible credible credible
# platforms platforms platforms platforms platforms platforms platforms platforms platforms
# liberty liberty liberty liberty liberty liberty liberty liberty
# rights rights rights rights rights rights rights rights
# enforcement enforcement enforcement enforcement enforcement enforcement enforcement enforcement
# valuable valuable valuable valuable valuable valuable valuable valuable
# timing timing timing timing timing timing timing timing
# expertise expertise expertise expertise expertise expertise expertise
# reliability reliability reliability reliability reliability reliability reliability
# transparent transparent transparent transparent transparent transparent transparent
# expertise expertise expertise expertise expertise expertise expertise
# functionality functionality functionality functionality functionality functionality functionality
# authority authority authority authority authority
# difficulty difficulty difficulty difficulty difficulty
# nuanced nuanced nuanced nuanced nuanced
# compulsory compulsory compulsory compulsory
# monitoring monitoring monitoring monitoring
